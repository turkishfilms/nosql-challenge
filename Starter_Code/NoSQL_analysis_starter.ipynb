# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient,ASCENDING, DESCENDING
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
uk_food = mongo["uk_food"]

# %%
# review the collections in our database
print(uk_food.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = uk_food["establishments"]

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene" : 20}
hygiene_20 = establishments.find(query)
# Use count_documents to display the number of documents in the result
hygiene_20_count = establishments.count_documents(query)
print(hygiene_20_count )
# Display the first document in the results using pprint
# pprint(hygiene_20[0])
# Out:
# 41

# %%
# Convert the result to a Pandas DataFrame
# pprint(hygiene_20[0])
hyg_20_list = list(hygiene_20)
hygiene_20_df =pd.DataFrame(hyg_20_list)
# Display the number of rows in the DataFrame
print(len(hygiene_20_df))
# Display the first 10 rows of the DataFrame
hygiene_20_df.head(5)
# Out:
# 41
#                         _id  FHRSID  ChangesByServerID  \
# 0  6453040c52bcd7017526fbe9  110681                  0
# 1  6453040d52bcd7017526ff6b  612039                  0
# 2  6453040d52bcd70175270273  730933                  0
# 3  6453040d52bcd70175270461  172735                  0
# 4  6453040d52bcd7017527047a  172953                  0
#
#   LocalAuthorityBusinessID         BusinessName  \
# 0                     4029  The Chase Rest Home
# 1                1970/FOOD           Brenalwood
# 2                1698/FOOD        Melrose Hotel
# 3             PI/000023858        Seaford Pizza
# 4             PI/000024532        Golden Palace
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query ={"$and":[{"LocalAuthorityName":{"$regex":"London"}},{"RatingValue": {"$gte":"4"}}]}
london_rv_4 = establishments.find(query)
# print(london_rv_4)
# Use count_documents to display the number of documents in the result
print(establishments.count_documents(query))
# Display the first document in the results using pprint
# pprint(london_rv_4[0])
# Out:
# 34

# %%
# Convert the result to a Pandas DataFrame
lrv_4_df =pd.DataFrame(list(london_rv_4))
# Display the number of rows in the DataFrame
print(len(lrv_4_df))
# Display the first 10 rows of the DataFrame
lrv_4_df.head(5)
# Out:
# 34
#                         _id   FHRSID  ChangesByServerID  \
# 0  6453041152bcd70175271605   621707                  0
# 1  6453041252bcd7017527192a  1130836                  0
# 2  6453041452bcd70175272478   293783                  0
# 3  6453041552bcd7017527327a   294474                  0
# 4  6453041552bcd7017527327b  1315095                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000014647              Tilbury Seafarers Centre
# 4             PI/000036464  Coombs Catering t/a The Lock and Key
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
# 3  Restaurant/Cafe/Canteen               1
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of '5', sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score
penang = establishments.find_one({"BusinessName": "Penang Flavours"})
# pprint(establishments.find_one())
degree_search = 0.01
latitude = penang["geocode"]["latitude"]
longitude = penang["geocode"]["longitude"]
print(latitude,longitude)

query = {"$and":[
                 {"RatingValue":"5"}, 
                 {"geocode.latitude": {"$lte": latitude + degree_search}},
                 {"geocode.longitude": {"$gte": longitude - degree_search}},
                 {"geocode.longitude": {"$lte": longitude + degree_search}},
                 {"geocode.latitude": {"$gt":  latitude - degree_search}}]}
sort = {"scores.Hygiene": ASCENDING}

penang_peers = establishments.find(query)
# # Print the results
establishments.count_documents(query)
# Out:
# 51.490142 0.08384
# 87

# %%
# Convert result to Pandas DataFrame
penang_peers_df =pd.DataFrame(list(penang_peers))

# %%
penang_peers_df.head(5)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  6453041a52bcd701752753f3  1069652                  0
# 1  6453041a52bcd7017527541b   695223                  0
# 2  6453041a52bcd7017527542c  1380578                  0
# 3  6453041a52bcd7017527544a   694609                  0
# 4  6453041a52bcd70175275462   694478                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000206841   TIWA N TIWA African Restaurant Ltd
# 1             PI/000178842                              Iceland
# 2                    14425  Howe and Co Fish and Chips - Van 17
# 3             PI/000116619                            Volunteer
# 4             PI/000086506                    Atlantic Fish Bar
#
#                             BusinessType  BusinessTypeID  \
# 0                Restaurant/Cafe/Canteen               1
# 1  Retailers - supermarkets/hypermarkets            7840
# 2                         Mobile caterer            7846
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0? 55

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
pipeline = [
    {"$match": {"scores.Hygiene" : 0}},
    {"$group": {"_id": "$LocalAuthorityName"}},
    {"$sort": {"scores.Hygiene": -1}}
]

results = list(establishments.aggregate(pipeline))
# Print the number of documents in the result
len(results)
# Print the first 10 results
# Out:
# 55

# %%
# Convert the result to a Pandas DataFrame
low_hygiene_df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print(len(low_hygiene_df))
# Display the first 5 rows of the DataFrame
low_hygiene_df.head(5)
# Out:
# 55
#    _id
# 0  530
# 1  531
# 2  894
# 3  112
# 4  179
